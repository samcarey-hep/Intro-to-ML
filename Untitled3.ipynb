# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import math
import matplotlib as mt
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, f1_score, recall_score
import seaborn as sns
import statistics
sns.set(style="whitegrid")
# %matplotlib inline

# %%
dp = pd.read_csv("adult.csv")
df=dp.replace('?', np.NaN)
df = df.drop(['age'], axis = 1)
df = df.drop(['fnlwgt'], axis = 1)
df = df.drop(['capital.gain'], axis = 1)
df = df.drop(['capital.loss'], axis = 1)
df = df.drop(['hours.per.week'], axis = 1)
df
# Out:
#       workclass     education  education.num      marital.status  \
# 0           NaN       HS-grad              9             Widowed
# 1       Private       HS-grad              9             Widowed
# 2           NaN  Some-college             10             Widowed
# 3       Private       7th-8th              4            Divorced
# 4       Private  Some-college             10           Separated
# ...         ...           ...            ...                 ...
# 32556   Private  Some-college             10       Never-married
# 32557   Private    Assoc-acdm             12  Married-civ-spouse
# 32558   Private       HS-grad              9  Married-civ-spouse
# 32559   Private       HS-grad              9             Widowed
# 32560   Private       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex native.country income
# 0                    NaN  Not-in-family  White  Female  United-States  <=50K
# 1        Exec-managerial  Not-in-family  White  Female  United-States  <=50K
# 2                    NaN      Unmarried  Black  Female  United-States  <=50K
# 3      Machine-op-inspct      Unmarried  White  Female  United-States  <=50K
# 4         Prof-specialty      Own-child  White  Female  United-States  <=50K
# ...                  ...            ...    ...     ...            ...    ...
# 32556    Protective-serv  Not-in-family  White    Male  United-States  <=50K
# 32557       Tech-support           Wife  White  Female  United-States  <=50K
# 32558  Machine-op-inspct        Husband  White    Male  United-States   >50K
# 32559       Adm-clerical      Unmarried  White  Female  United-States  <=50K
# 32560       Adm-clerical      Own-child  White    Male  United-States  <=50K
#
# [32561 rows x 10 columns]

# %%
def weighted_entropy(data, col_num):
    entropies = []
    n_s = []
    entropy_of_attribute = entropy(data[:,col_num])
    for value in columns[col_num]:
        candidate_child = data[data[:,col_num] == value]
        n_s.append(len(candidate_child))
        entropies.append(entropy(candidate_child[:,6]))
    n_s = np.array(n_s)
    n_s = n_s / np.sum(n_s)
    weighted_entropy = n_s.dot(entropies)
    return weighted_entropy, entropy_of_attribute
    
def entropy(data):
    classes = np.unique(data)
    n = len(data)
    n_s = []
    for class_ in classes:
        n_s.append(len(data[data==class_]))
    n_s = np.array(n_s)
    n_s = n_s/n
    n_s = n_s * np.log2(n_s)
    return max(0,-np.sum(n_s))

# %%
def build_node(df, entropy, label, depth, class_="TBD", parent=None):
    new_node = dict()
    new_node['df'] = df
    new_node['entropy'] = entropy
    new_node['label'] = label
    new_node['depth'] = depth
    new_node['class'] = class_
    new_node['parent'] = parent
    new_node['children'] = []
    return new_node

root = build_node(df, entropy(df[:,6]), "all data", 0)
classes = np.unique(root['df'][:,6])
print(classes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 6)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /var/folders/kw/hb79l80n2mv9r52s0n0zgx200000gn/T/ipykernel_28069/3767849058.py in <module>
#      10     return new_node
#      11
# ---> 12 root = build_node(df, entropy(df[:,6]), "all data", 0)
#      13 classes = np.unique(root['df'][:,6])
#      14 print(classes)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3634                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635                 #  the TypeError.
# -> 3636                 self._check_indexing_error(key)
#    3637                 raise
#    3638
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    5649             # if key is not a scalar, directly raise an error (the code below
#    5650             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5651             raise InvalidIndexError(key)
#    5652
#    5653     @cache_readonly
#
# InvalidIndexError: (slice(None, None, None), 6)
